# %%
# !{sys.executable} -m conda install astropy
# Out:
# /bin/bash: {sys.executable}: command not found

# %%
from utils import Candidate
from utils import Quadrant
import pandas as pd
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
#from astropy.visualization import ZScaleItnterval
from astropy.visualization import ZScaleInterval
import astropy.wcs as wcs
#from crowdsource import crowdsource_base

import psf
import crowdsource_base

# %% [markdown]
# ### Goal:
# 1. Do Dr. Knop's crowdsource on the reference image. Make sure the model and subtraction are much better.
# 2. Generate a reference csv file.
# 3. Based on the reference csv file, do Dr. Knop's crowdsource on another random image. Make sure the model and subtraction are much better.
# 4. Experiment with using gaussian vs. moffat psfs and toggling the refit_sky and other parameters on and off.

# %%
def get_weight(weighthdul, c):
    return np.flipud(weighthdul[1].data[c[2]:c[3], c[0]:c[1]]) # Gets flipped because of numpy indexing

def get_full_pos(pars, s):
    ypres = np.reshape(pars[0]["y"], (pars[0]["x"].shape[0], 1))
    xpres = np.reshape(pars[0]["x"], (pars[0]["x"].shape[0], 1))

    xs = xpres[xpres>0][ypres[xpres>0]>0]
    ys = ypres[xpres>0][ypres[xpres>0]>0]

    xs = np.reshape(xs, (xs.shape[0], 1))
    ys = np.reshape(ys, (xs.shape[0], 1))

    ypre = xs - s
    xpre = ys - s

    y = -1*ypre
    x = xpre

    ypre = y + s - 1
    xpre = x + s

    xref = xpre + ymin
    yref = ypre + xmin
    
    return xref, yref

def get_radecs(imhdul, xref, yref):
    ws = wcs.WCS(imhdul[1].header)  # create a wcs object with the quadrant object's header
    return ws.wcs_pix2world(np.transpose(np.array([xref, yref+0.5]))[0], 0)  
    # return the Ra/Dec positions as a numpy array (ofset by 0.5 pixels to account for differences in numpy indexed image and full image xlim/ylim)

# %%
# Get the reference and test images

name = "DC21saaw"
radec = (270.31184, -28.77637)
c = Candidate(name, radec)
c.start()
iid = c.get_image_ids()
imref_fp, wref_fp = c.get_fp("c4d_210322_091756_ori") # Tuple of image and weight file
imfnames, wfnames = zip(*c.get_all_fps()) # List of tuples of image and weight files
c.close()

# %%
# STEP 1: Define picture radius and Ra Decs. Load Images
s = 32
radec = (270.31177, -28.776405) # Updated ra/dec manually
radec = (270.31178, -28.77640)
imhdul = fits.open(imref_fp) # get a file
weighthdul = fits.open(wref_fp)

# Create a quadrant and get image tile
q = Quadrant(imhdul, (2*s, 2*s)) # start a tile
subim, c = q.get_tile((radec[0], radec[1])) # Get the image centered on the int near radect
ymin, ymax, xmin, xmax = c

# weight = np.flipud(weighthdul[1].data[c[2]:c[3], c[0]:c[1]])
weight = get_weight(weighthdul, c)

psf_ = psf.gaussian_psf(4, deriv=False) # get the psf stamps
psf_ = np.reshape(psf_, (19, 19)) # reshape the psf into the shape the SimplePSF object needs.
psf__ = psf.SimplePSF(psf_) # make a SimplePSF psf object with the stamps.

#psf__ = psf.MoffatPSF(4, beta=3)
    
#CROWDSOURCE GET XS AND YS
pars = crowdsource_base.fit_im(subim, psf__, weight=weight, 
                           verbose=True, miniter=4, maxiter=10, 
                           refit_psf=True, derivcentroids=True, refit_sky = False) # Get the crowdsource fit (including sky subtraction).



# Get Full Postions

xref, yref = get_full_pos(pars, s)
radecs = get_radecs(imhdul, xref, yref)
# Out:
# Extension None, iteration  1, found     35 sources;    0 close and    0 faint sources removed.
# Extension None, iteration  2, found     16 sources;    0 close and    0 faint sources removed.
# Fewer than 5 stars accepted in image, keeping original PSF
# Extension None, iteration  3, found      2 sources;    0 close and    0 faint sources removed.
# Fewer than 5 stars accepted in image, keeping original PSF
# Extension None, iteration  4, found      0 sources;    0 close and    0 faint sources removed.

# %%
imhdul = fits.open(imref_fp) # get another file
weighthdul = fits.open(wref_fp)

# imhdul = fits.open(imfnames[15]) # get a file
# weighthdul = fits.open(wfnames[15])


q = Quadrant(imhdul, (2*s, 2*s)) # start a tile
subim, c = q.get_tile((radec[0], radec[1])) # Get the image centered on the int near radect
ymin, ymax, xmin, xmax = c
weight = np.flipud(weighthdul[1].data[c[2]:c[3], c[0]:c[1]])

def get_xys(imhdul, radecs):   
    ws = wcs.WCS(imhdul[1].header)  # create a wcs object with the quadrant object's header
    xys = ws.wcs_world2pix(radecs, 0)  # return the Ra/Dec positions as a numpy array

    x = np.transpose(xys)[0]
    y = np.transpose(xys)[1]
    
    return x, y

x, y = get_xys(imhdul, radecs)

def get_rel_pos(xref, yref, s):
    # Get Relative Positions
    xref = x - ymin
    yref = y - xmin

    xref = xref - s
    yref = yref - s

    yref = -1*yref

    xref = xref + s
    yref = yref + s

    yref = yref-1
    
    return xref, yref

xref, yref = get_rel_pos(

# Run Crowdsource Forced Fit

psf_ = psf.gaussian_psf(4, deriv=False) # get the psf stamps
psf_ = np.reshape(psf_, (19, 19)) # reshape the psf into the shape the SimplePSF object needs.
psf__ = psf.SimplePSF(psf_) # make a SimplePSF psf object with the stamps.

psf__ = psf.MoffatPSF(4, beta=3)
    
#CROWDSOURCE GET XS AND YS
pars_ = crowdsource_base.fit_im_force(subim, 
                                 yref, xref, 
                                 psf__, weight = weight, psfderiv = False, derivcentroids=False, refit_psf=True, refit_sky = True, startsky = 0) # Do the forced fit
# Out:
# Iteration 1, median sky   0.00
# Fewer than 5 stars accepted in image, keeping original PSF
# Iteration 2, median sky  19.68
# Fewer than 5 stars accepted in image, keeping original PSF
# Iteration 3, median sky  36.65
# Fewer than 5 stars accepted in image, keeping original PSF
# Iteration 4, median sky  44.83

# %%
# STEP 1: Get Reference Image Centered on Ra/Dec

s = 32
radec = (270.31177, -28.776405) # Updated ra/dec manually
radec = (270.31178, -28.77640)

imhdul = fits.open(imref_fp) # get a file
weighthdul = fits.open(wref_fp)

# imhdul = fits.open(imfnames[0]) # get a file
# weighthdul = fits.open(wfnames[0])

q = Quadrant(imhdul, (2*s, 2*s)) # start a tile
xrel, yrel = q.get_rel_xy((radec[0], radec[1])) # change this to get_rel_center because it only does this with a centering...!!!


# PLOT QUADRANT IMAGE
subim, c = q.get_tile((radec[0], radec[1])) # Get the image centered on the int near radect
ymin, ymax, xmin, xmax = c
weight = np.flipud(weighthdul[1].data[c[2]:c[3], c[0]:c[1]])

plt.imshow(subim, vmin=-1600, vmax=1600)
plt.scatter(xrel, yrel, s=50, color = "red", alpha = 1) # plot the center and the x/y for ra/dec
plt.show()

vmin, vmax = ZScaleInterval().get_limits(weighthdul[1].data)
# vmin, vmax = -1600, 1600
plt.imshow(weight, vmin=vmin, vmax=vmax)
plt.scatter(xrel, yrel, s=50, color = "red", alpha = 1) # plot the center and the x/y for ra/dec
plt.show()

# %%
# STEP 2: Do Crowdsource on the reference image

psf_ = psf.gaussian_psf(4, deriv=False) # get the psf stamps
psf_ = np.reshape(psf_, (19, 19)) # reshape the psf into the shape the SimplePSF object needs.
psf__ = psf.SimplePSF(psf_) # make a SimplePSF psf object with the stamps.

#psf__ = psf.MoffatPSF(4, beta=3)
    
#CROWDSOURCE GET XS AND YS
pars = crowdsource_base.fit_im(subim, psf__, weight=weight, 
                           verbose=True, miniter=4, maxiter=10, 
                           refit_psf=True, derivcentroids=True, refit_sky = False) # Get the crowdsource fit (including sky subtraction).

print("starting reference image")
plt.imshow(subim, vmin=-1600, vmax=1600 )
plt.scatter(pars[0]["y"], pars[0]["x"], s=50, color = "red", alpha = 1, marker = "x")
plt.show()

print("reference model image")
plt.imshow(pars[1], vmin=-1600, vmax=1600 )
plt.scatter(pars[0]["y"], pars[0]["x"], s=50, color = "red", alpha = 1, marker = "x")
plt.show()

print("reference difference image")
plt.imshow(subim - pars[1], vmin=-1600, vmax=1600 )
plt.show()

print("starting reference image")
plt.imshow(subim, vmin=-1600, vmax=1600 )
plt.scatter(pars[0]["y"], pars[0]["x"], s=50, color = "red", alpha = 1, marker = "x")
plt.show()

print(min(pars[0]["x"]), min(pars[0]["y"]))
# Out:
# Extension None, iteration  1, found     35 sources;    0 close and    0 faint sources removed.
# Extension None, iteration  2, found     16 sources;    0 close and    0 faint sources removed.
# Fewer than 5 stars accepted in image, keeping original PSF
# Extension None, iteration  3, found      2 sources;    0 close and    0 faint sources removed.
# Fewer than 5 stars accepted in image, keeping original PSF
# Extension None, iteration  4, found      0 sources;    0 close and    0 faint sources removed.
# starting reference image
# reference model image
# reference difference image
# starting reference image
# 1.109036311507225 -0.499

# %%
# STEP 3: Transform xy relative coordinates to full x y coordinates

# Plot the crowdsource positions over the image
print("starting reference image")
fig, ax = plt.subplots()
plt.imshow(subim, vmin=-1600, vmax=1600 )
plt.scatter(pars[0]["y"], pars[0]["x"], s=50, color = "red", alpha = 1, marker = "x")

plt.show()


# Calculate the full positions
ypres = np.reshape(pars[0]["y"], (pars[0]["x"].shape[0], 1))
xpres = np.reshape(pars[0]["x"], (pars[0]["x"].shape[0], 1))

xs = xpres[xpres>0][ypres[xpres>0]>0]
ys = ypres[xpres>0][ypres[xpres>0]>0]

print(xs, ys)

xs = np.reshape(xs, (xs.shape[0], 1))
ys = np.reshape(ys, (xs.shape[0], 1))

ypre = xs - s
xpre = ys - s

y = -1*ypre
x = xpre

ypre = y + s - 1
xpre = x + s

xref = xpre + ymin
yref = ypre + xmin

# xref = xs + ymin
# yref = ys + xmin

# Plot the full crowdsource positions over the image, zoom in with xlim/

print("Full Crowdsource Positions")
fig, ax = plt.subplots()
ax.imshow(imhdul[1].data, vmin=-1600, vmax=1600 )
ax.scatter(xref, yref, s=50, color = "red", alpha = 1, marker = "x")

# plt.xlim(ymin-0.5, ymax-0.5)
# plt.ylim(xmin-0.5, xmax-0.5)

plt.xlim(ymin, ymax)
plt.ylim(xmin, xmax)

plt.show()
# Out:
# starting reference image
# [ 1.10903631  5.79620627  8.05036904 10.31247551 10.75436253 12.49777293
#  13.83089396 17.39687008 20.99049579 21.51295146 22.75832714 23.40824456
#  26.04271819 30.57776402 30.96317935 33.10898139 33.03688204 33.82434268
#  33.44059632 34.15511079 41.83555521 41.28609816 43.39686048 46.66636692
#  49.20858438 49.3881521  49.921094   51.89853243 60.20177567 59.70839288
#  61.45953268 61.53193374 62.56252391 63.499       2.49061281  5.64976334
#   5.9961547   9.02256715  9.80983246 14.12441722 20.67871571 27.68296976
#  30.01894984 43.4087634  44.7040844  50.0320919  52.11598543 53.07528311
#  56.86352021 22.8267982  23.35654642] [39.81003416 58.67791221 43.61000928 14.7960143   0.50629849 30.13255781
#  49.61865415  5.0633468   9.77277999 33.55670116 28.51366148 17.87013035
#  42.90258623 57.68933247 32.8098224   0.42077847 51.21314642  9.08032079
#  42.38411325 21.64701037 27.40991005 33.67703193 41.41175064  2.59143004
#  10.31992967 44.23477502 59.06097019 32.04699261 17.41832344 54.6386961
#  60.54365342 23.25830382 41.21222167  9.60058728 34.81816811  2.43634196
#  13.00647752 23.3885929  37.95169516 14.27382506 45.73078552 61.84205958
#  24.16205111 21.67697438  8.02208478 49.48602152 38.99983313 25.57824036
#  33.05702531 49.96897116 56.29952723]
# Full Crowdsource Positions

# %%
# STEP 4: Transform xy full coordinates to Ra/Decs

# Plot the full image with xy full coordinates
fig, ax = plt.subplots()
ax.imshow(imhdul[1].data, vmin=-1600, vmax=1600 )
ax.scatter(xref, yref+0.5, s=50, color = "red", alpha = 1, marker = "x")

plt.xlim(ymin, ymax)
plt.ylim(xmin, xmax)

plt.show()


# Convert to xy full coordinates to Ra/Decs
ws = wcs.WCS(imhdul[1].header)  # create a wcs object with the quadrant object's header
radecs = ws.wcs_pix2world(np.transpose(np.array([xref, yref+0.5]))[0], 0)  # return the Ra/Dec positions as a numpy array


# Convert back to xy full coordinates and plot the full image
xys = ws.wcs_world2pix(radecs, 0)
x = np.transpose(xys)[0]
y = np.transpose(xys)[1]

fig, ax = plt.subplots()
ax.imshow(imhdul[1].data, vmin=-1600, vmax=1600 )
ax.scatter(x, y, s=50, color = "red", alpha = 1, marker = "x")

plt.xlim(ymin, ymax)
plt.ylim(xmin, xmax)

plt.show()

# %%
# STEP 5 & 6: Grab another image and center it on the Ra/Dec

imhdul = fits.open(imref_fp) # get a file
weighthdul = fits.open(wref_fp)

imhdul = fits.open(imfnames[15]) # get a file
weighthdul = fits.open(wfnames[15])


q = Quadrant(imhdul, (2*s, 2*s)) # start a tile
xrel, yrel = q.get_rel_xy((radec[0], radec[1]))


# PLOT QUADRANT IMAGE
subim, c = q.get_tile((radec[0], radec[1])) # Get the image centered on the int near radect
ymin, ymax, xmin, xmax = c
weight = np.flipud(weighthdul[1].data[c[2]:c[3], c[0]:c[1]])

plt.imshow(subim, vmin=-1600, vmax=1600)
plt.scatter(xrel, yrel, s=50, color = "red", alpha = 1) # plot the center and the x/y for ra/dec
plt.show()

vmin, vmax = ZScaleInterval().get_limits(weighthdul[1].data)
plt.imshow(weight, vmin=vmin, vmax=vmax)
plt.scatter(xrel, yrel, s=50, color = "red", alpha = 1) # plot the center and the x/y for ra/dec
plt.show()

# %%
# STEP 7: Transform the radecs to full coords using the new image header

ws = wcs.WCS(imhdul[1].header)  # create a wcs object with the quadrant object's header
xys = ws.wcs_world2pix(radecs, 0)  # return the Ra/Dec positions as a numpy array

x = np.transpose(xys)[0]
y = np.transpose(xys)[1]

fig, ax = plt.subplots()
ax.imshow(imhdul[1].data, vmin=-1600, vmax=1600 )
ax.scatter(x, y, s=50, color = "red", alpha = 1, marker = "x")

plt.xlim(ymin, ymax)
plt.ylim(xmin, xmax)

# plt.xlim(ymin + 60, ymax - 60)
# plt.ylim(xmin + 60, xmax - 60)

# plt.xlim(ymin - 0, ymin + 20)
# plt.ylim(xmin - 0, xmin + 20)


plt.show()

# %%
# STEP 8: Transform full xy coordinates to relative xy coordinates

# Plot the full picture for reference:
ws = wcs.WCS(imhdul[1].header)  # create a wcs object with the quadrant object's header
xys = ws.wcs_world2pix(radecs, 0)  # return the Ra/Dec positions as a numpy array

x = np.transpose(xys)[0]
y = np.transpose(xys)[1]

fig, ax = plt.subplots()
ax.imshow(imhdul[1].data, vmin=-1600, vmax=1600 )
ax.scatter(x, y, s=50, color = "red", alpha = 1, marker = "x")

# plt.xlim(ymin-1, ymax+1) # The picture is adjusted to account for xlim vs numpy indexing.
# plt.ylim(xmin-1, xmax+1)

plt.xlim(ymin, ymax)
plt.ylim(xmin, xmax)

plt.show()


# Now plot the relative coordinates on subim:
fig, ax = plt.subplots()
ax.imshow(subim, vmin=-1600, vmax=1600 )

xref = x - ymin
yref = y - xmin

xref = xref - s
yref = yref - s

yref = -1*yref

xref = xref + s
yref = yref + s

print(xref.shape, yref.shape)

yref = yref-1

xs = xref[xref>0][yref[xref>0]>0]

print(xref.shape, yref[xref>0].shape)
ys = yref[xref>0][yref[xref>0]>0]

print(xref.shape, yref.shape)

ax.scatter(xref, yref, s=50, color = "red", alpha = 1, marker = "x")
plt.show()

print(min(xref), min(yref))
# Out:
# (51,) (51,)
# (51,) (51,)
# (51,) (51,)
# 0.18907675274385838 -0.16496470328252144

# %%
# STEP 9: Run a forced fit using centered new image, weight, and relative xys

psf_ = psf.gaussian_psf(4, deriv=False) # get the psf stamps
psf_ = np.reshape(psf_, (19, 19)) # reshape the psf into the shape the SimplePSF object needs.
psf__ = psf.SimplePSF(psf_) # make a SimplePSF psf object with the stamps.

psf__ = psf.MoffatPSF(4, beta=3)
    
#CROWDSOURCE GET XS AND YS
pars_ = crowdsource_base.fit_im_force(subim, 
                                 yref, xref, 
                                 psf__, weight = weight, psfderiv = False, derivcentroids=False, refit_psf=True, refit_sky = True, startsky = 0) # Do the forced fit
  
print("starting reference image")
plt.imshow(subim, vmin=-1600, vmax=1600 )
plt.show()

print("reference model image")
plt.imshow(pars[1], vmin=-1600, vmax=1600 )
plt.scatter(pars[0]["y"], pars[0]["x"], s=50, color = "red", alpha = 1, marker = "x")
plt.show()

print("reference difference image")
plt.imshow(subim - pars[1], vmin=-1600, vmax=1600 )
plt.show()
# Out:
# Iteration 1, median sky   0.00
# Fewer than 5 stars accepted in image, keeping original PSF
# Iteration 2, median sky  30.02
# Fewer than 5 stars accepted in image, keeping original PSF
# Iteration 3, median sky  32.80
# Fewer than 5 stars accepted in image, keeping original PSF
# Iteration 4, median sky  34.96
# starting reference image
# reference model image
# reference difference image
